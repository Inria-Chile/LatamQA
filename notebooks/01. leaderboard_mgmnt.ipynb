# %% [markdown]
# # Managing leaderboard
#
# Helper to do some manual edits to the leaderboard dataset, and push it to the Hugging Face Hub.

# %%
import pandas as pd
from datasets import Dataset, load_dataset

from latamqa.leaderboard import LEADERBOARD_DATASET

# %%
LEADERBOARD_DATASET

# %%
current_leaderboard = load_dataset(LEADERBOARD_DATASET, split="train")

# %%
current_leaderboard

# %%
leaderboard_df = current_leaderboard.to_pandas()

# %%
leaderboard_df

# %%
# leaderboard_df.to_csv("leaderboard.csv", index=False)

# %%
leaderboard_df = pd.read_csv("leaderboard.csv")

# %%
leaderboard_df

# %%
updated_dataset = Dataset.from_pandas(leaderboard_df)

# %%
updated_dataset

# %%
updated_dataset.push_to_hub(LEADERBOARD_DATASET, private=True)
